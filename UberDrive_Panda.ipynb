# %%
#Reading first CSV file

# %%
import pandas as pd
df = pd.read_csv("UberDrive.csv")
df
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*         PURPOSE*
# 0          Fort Pierce      5.1   Meal/Entertain
# ...

# %%
#Printing DATA Types

# %%
df.dtypes
# Out:
# START_DATE*     object
# END_DATE*       object
# CATEGORY*       object
# START*          object
# STOP*           object
# MILES*         float64
# PURPOSE*        object
# dtype: object

# %%
#Print first 5 rows

# %%
df.head()
# Out:
#       START_DATE*       END_DATE* CATEGORY*       START*            STOP*  \
# 0  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# 1   1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2  1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  1/6/2016 14:42  1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES*         PURPOSE*
# 0     5.1   Meal/Entertain
# 1     5.0              NaN
# 2     4.8  Errand/Supplies
# 3     4.7          Meeting
# 4    63.7   Customer Visit

# %%
#Print First 10 rows

# %%
df.head(n=10)
# Out:
#        START_DATE*        END_DATE* CATEGORY*           START*  \
# 0   1/1/2016 21:11   1/1/2016 21:17  Business      Fort Pierce
# 1    1/2/2016 1:25    1/2/2016 1:37  Business      Fort Pierce
# 2   1/2/2016 20:25   1/2/2016 20:38  Business      Fort Pierce
# 3   1/5/2016 17:31   1/5/2016 17:45  Business      Fort Pierce
# 4   1/6/2016 14:42   1/6/2016 15:49  Business      Fort Pierce
# 5   1/6/2016 17:15   1/6/2016 17:19  Business  West Palm Beach
# 6   1/6/2016 17:30   1/6/2016 17:35  Business  West Palm Beach
# 7   1/7/2016 13:27   1/7/2016 13:33  Business             Cary
# 8   1/10/2016 8:05   1/10/2016 8:25  Business             Cary
# 9  1/10/2016 12:17  1/10/2016 12:44  Business          Jamaica
#
#              STOP*  MILES*         PURPOSE*
# 0      Fort Pierce     5.1   Meal/Entertain
# 1      Fort Pierce     5.0              NaN
# 2      Fort Pierce     4.8  Errand/Supplies
# 3      Fort Pierce     4.7          Meeting
# 4  West Palm Beach    63.7   Customer Visit
# ...

# %%
#Print Last 5 rows

# %%
df.tail()
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*        PURPOSE*
# 1151  Unknown Location      3.9  Temporary Site
# 1152  Unknown Location     16.2         Meeting
# 1153           Gampaha      6.4  Temporary Site
# 1154         Ilukwatta     48.2  Temporary Site
# 1155               NaN  12204.7             NaN

# %%
df.tail(n=10)
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 1146  12/30/2016 11:31  12/30/2016 11:56  Business           Kar?chi
# 1147  12/30/2016 15:41  12/30/2016 16:03  Business           Kar?chi
# 1148  12/30/2016 16:45  12/30/2016 17:08  Business           Kar?chi
# 1149  12/30/2016 23:06  12/30/2016 23:10  Business           Kar?chi
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business           Kar?chi
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*         PURPOSE*
# 1146           Kar?chi      2.9  Errand/Supplies
# 1147           Kar?chi      4.6  Errand/Supplies
# 1148           Kar?chi      4.6          Meeting
# ...

# %%
# By default pandas read everything as String and Integers 
# Our START_DATE* and END_DATE* is string 
# Let's convert it into DATE AND TIME

# %%
import pandas as pd

# Load the CSV file into a DataFrame
df = pd.read_csv('UberDrive.csv')

# Remove the last row which contains the "Totals" string
df = df[:-1]

# Convert 'START_DATE*' and 'END_DATE*' columns to datetime
df['START_DATE*'] = pd.to_datetime(df['START_DATE*'])
df['END_DATE*'] = pd.to_datetime(df['END_DATE*'])

# Display the first few rows of the DataFrame to verify the changes
df
# Out:
#              START_DATE*           END_DATE* CATEGORY*            START*  \
# 0    2016-01-01 21:11:00 2016-01-01 21:17:00  Business       Fort Pierce
# 1    2016-01-02 01:25:00 2016-01-02 01:37:00  Business       Fort Pierce
# 2    2016-01-02 20:25:00 2016-01-02 20:38:00  Business       Fort Pierce
# 3    2016-01-05 17:31:00 2016-01-05 17:45:00  Business       Fort Pierce
# 4    2016-01-06 14:42:00 2016-01-06 15:49:00  Business       Fort Pierce
# ...                  ...                 ...       ...               ...
# 1150 2016-12-31 01:07:00 2016-12-31 01:14:00  Business           Kar?chi
# 1151 2016-12-31 13:24:00 2016-12-31 13:42:00  Business           Kar?chi
# 1152 2016-12-31 15:03:00 2016-12-31 15:38:00  Business  Unknown Location
# 1153 2016-12-31 21:32:00 2016-12-31 21:50:00  Business        Katunayake
# 1154 2016-12-31 22:08:00 2016-12-31 23:51:00  Business           Gampaha
#
#                  STOP*  MILES*         PURPOSE*
# ...

# %%
df.dtypes
# Out:
# START_DATE*    datetime64[ns]
# END_DATE*      datetime64[ns]
# CATEGORY*              object
# START*                 object
# STOP*                  object
# MILES*                float64
# PURPOSE*               object
# dtype: object

# %%
#Let's see the description of Data

# %%
df.describe()
# Out:
#                          START_DATE*                      END_DATE*  \
# count                           1155                           1155
# mean   2016-07-16 23:44:33.402597376  2016-07-17 00:07:47.999999744
# min              2016-01-01 21:11:00            2016-01-01 21:17:00
# 25%              2016-04-01 02:10:00            2016-04-01 02:35:00
# 50%              2016-07-21 17:17:00            2016-07-21 17:23:00
# 75%              2016-10-27 21:06:30            2016-10-27 21:21:00
# max              2016-12-31 22:08:00            2016-12-31 23:51:00
# std                              NaN                            NaN
#
#             MILES*
# count  1155.000000
# mean     10.566840
# min       0.500000
# 25%       2.900000
# 50%       6.000000
# 75%      10.400000
# max     310.300000
# std      21.579106

# %%
#Selecting/Indexing

# %%
df.iloc[0:5,0:4] #First is row[0:5] and Second is Columns[0:4]
# Out:
#           START_DATE*           END_DATE* CATEGORY*       START*
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce

# %%
#Print all the rows but first 4 columns

# %%
df.iloc[:,0:4]
# Out:
#              START_DATE*           END_DATE* CATEGORY*            START*
# 0    2016-01-01 21:11:00 2016-01-01 21:17:00  Business       Fort Pierce
# 1    2016-01-02 01:25:00 2016-01-02 01:37:00  Business       Fort Pierce
# 2    2016-01-02 20:25:00 2016-01-02 20:38:00  Business       Fort Pierce
# 3    2016-01-05 17:31:00 2016-01-05 17:45:00  Business       Fort Pierce
# 4    2016-01-06 14:42:00 2016-01-06 15:49:00  Business       Fort Pierce
# ...                  ...                 ...       ...               ...
# 1150 2016-12-31 01:07:00 2016-12-31 01:14:00  Business           Kar?chi
# 1151 2016-12-31 13:24:00 2016-12-31 13:42:00  Business           Kar?chi
# 1152 2016-12-31 15:03:00 2016-12-31 15:38:00  Business  Unknown Location
# 1153 2016-12-31 21:32:00 2016-12-31 21:50:00  Business        Katunayake
# 1154 2016-12-31 22:08:00 2016-12-31 23:51:00  Business           Gampaha
#
# [1155 rows x 4 columns]

# %%
#Print all the rows but only print colomns till second last (Miles)

# %%
df.iloc[:,:-1]
# Out:
#              START_DATE*           END_DATE* CATEGORY*            START*  \
# 0    2016-01-01 21:11:00 2016-01-01 21:17:00  Business       Fort Pierce
# 1    2016-01-02 01:25:00 2016-01-02 01:37:00  Business       Fort Pierce
# 2    2016-01-02 20:25:00 2016-01-02 20:38:00  Business       Fort Pierce
# 3    2016-01-05 17:31:00 2016-01-05 17:45:00  Business       Fort Pierce
# 4    2016-01-06 14:42:00 2016-01-06 15:49:00  Business       Fort Pierce
# ...                  ...                 ...       ...               ...
# 1150 2016-12-31 01:07:00 2016-12-31 01:14:00  Business           Kar?chi
# 1151 2016-12-31 13:24:00 2016-12-31 13:42:00  Business           Kar?chi
# 1152 2016-12-31 15:03:00 2016-12-31 15:38:00  Business  Unknown Location
# 1153 2016-12-31 21:32:00 2016-12-31 21:50:00  Business        Katunayake
# 1154 2016-12-31 22:08:00 2016-12-31 23:51:00  Business           Gampaha
#
#                  STOP*  MILES*
# 0          Fort Pierce     5.1
# ...

# %%
#Filtering ; loc is used lebal based INDEXING iloc is used for Integer based Indexing as shown above

# %%
sdf = df[df["MILES*"] > 10] # This will print Miles greater then 10
sdfc = sdf.loc[:,["START_DATE*","MILES*"]]
sdfc.head()
# Out:
#            START_DATE*  MILES*
# 4  2016-01-06 14:42:00    63.7
# 9  2016-01-10 12:17:00    16.5
# 10 2016-01-10 15:08:00    10.8
# 22 2016-01-12 16:02:00    15.1
# 23 2016-01-13 13:54:00    11.2

# %%
df
# Out:
#              START_DATE*           END_DATE* CATEGORY*            START*  \
# 0    2016-01-01 21:11:00 2016-01-01 21:17:00  Business       Fort Pierce
# 1    2016-01-02 01:25:00 2016-01-02 01:37:00  Business       Fort Pierce
# 2    2016-01-02 20:25:00 2016-01-02 20:38:00  Business       Fort Pierce
# 3    2016-01-05 17:31:00 2016-01-05 17:45:00  Business       Fort Pierce
# 4    2016-01-06 14:42:00 2016-01-06 15:49:00  Business       Fort Pierce
# ...                  ...                 ...       ...               ...
# 1150 2016-12-31 01:07:00 2016-12-31 01:14:00  Business           Kar?chi
# 1151 2016-12-31 13:24:00 2016-12-31 13:42:00  Business           Kar?chi
# 1152 2016-12-31 15:03:00 2016-12-31 15:38:00  Business  Unknown Location
# 1153 2016-12-31 21:32:00 2016-12-31 21:50:00  Business        Katunayake
# 1154 2016-12-31 22:08:00 2016-12-31 23:51:00  Business           Gampaha
#
#                  STOP*  MILES*         PURPOSE*
# ...

# %%
# Find all the rides from New York

# %%
df.loc[df["START*"] == "New York"]
# Out:
#             START_DATE*           END_DATE* CATEGORY*    START*  \
# 10  2016-01-10 15:08:00 2016-01-10 15:51:00  Business  New York
# 22  2016-01-12 16:02:00 2016-01-12 17:00:00  Business  New York
# 106 2016-02-14 16:35:00 2016-02-14 17:02:00  Business  New York
# 423 2016-06-10 15:19:00 2016-06-10 16:28:00  Business  New York
#
#                 STOP*  MILES* PURPOSE*
# 10             Queens    10.8  Meeting
# 22      Queens County    15.1  Meeting
# 106  Long Island City    13.0  Meeting
# 423           Jamaica    16.3  Meeting

# %%
# Find all the rides in MILES from New York

# %%
df.loc[df["START*"] == "New York",["MILES*"]]
# Out:
#      MILES*
# 10     10.8
# 22     15.1
# 106    13.0
# 423    16.3

# %%
# Find out all the rides to Cary and New York

# %%
my_rides = df.loc[df["START*"].isin(["Cary","New York"])]
my_rides.head(n=10)
# Out:
#         START_DATE*        END_DATE* CATEGORY*    START*          STOP*  \
# 7    1/7/2016 13:27   1/7/2016 13:33  Business      Cary           Cary
# 8    1/10/2016 8:05   1/10/2016 8:25  Business      Cary    Morrisville
# 10  1/10/2016 15:08  1/10/2016 15:51  Business  New York         Queens
# 22  1/12/2016 16:02  1/12/2016 17:00  Business  New York  Queens County
# 28  1/15/2016 11:43  1/15/2016 12:03  Business      Cary         Durham
# 30  1/18/2016 14:55  1/18/2016 15:06  Business      Cary           Cary
# 34  1/20/2016 10:36  1/20/2016 11:11  Business      Cary        Raleigh
# 37  1/21/2016 14:25  1/21/2016 14:29  Business      Cary           Cary
# 38  1/21/2016 14:43  1/21/2016 14:51  Business      Cary           Cary
# 39  1/21/2016 16:01  1/21/2016 16:06  Business      Cary           Cary
#
#     MILES*         PURPOSE*
# 7      0.8          Meeting
# 8      8.3          Meeting
# 10    10.8          Meeting
# 22    15.1          Meeting
# 28    10.4   Meal/Entertain
# ...

# %%
# As we can see our indexing is starting from 7 lets reset it and make it start from 1

# %%
my_rides.reset_index(inplace = True, drop = True)
my_rides.head(n=10)
# Out:
#        START_DATE*        END_DATE* CATEGORY*    START*          STOP*  \
# 0   1/7/2016 13:27   1/7/2016 13:33  Business      Cary           Cary
# 1   1/10/2016 8:05   1/10/2016 8:25  Business      Cary    Morrisville
# 2  1/10/2016 15:08  1/10/2016 15:51  Business  New York         Queens
# 3  1/12/2016 16:02  1/12/2016 17:00  Business  New York  Queens County
# 4  1/15/2016 11:43  1/15/2016 12:03  Business      Cary         Durham
# 5  1/18/2016 14:55  1/18/2016 15:06  Business      Cary           Cary
# 6  1/20/2016 10:36  1/20/2016 11:11  Business      Cary        Raleigh
# 7  1/21/2016 14:25  1/21/2016 14:29  Business      Cary           Cary
# 8  1/21/2016 14:43  1/21/2016 14:51  Business      Cary           Cary
# 9  1/21/2016 16:01  1/21/2016 16:06  Business      Cary           Cary
#
#    MILES*         PURPOSE*
# 0     0.8          Meeting
# 1     8.3          Meeting
# 2    10.8          Meeting
# 3    15.1          Meeting
# 4    10.4   Meal/Entertain
# ...

# %%
# Sorting

# %%
df.sort_values(by=["MILES*"],ascending = False).head(n=10)
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 1155            Totals               NaN       NaN               NaN
# 269    3/25/2016 16:52   3/25/2016 22:22  Business             Latta
# 270    3/25/2016 22:54    3/26/2016 1:39  Business      Jacksonville
# 881   10/30/2016 15:22  10/30/2016 18:23  Business         Asheville
# 776    9/27/2016 21:01    9/28/2016 2:37  Business  Unknown Location
# 546    7/14/2016 16:39   7/14/2016 20:05  Business       Morrisville
# 559    7/17/2016 12:20   7/17/2016 15:25  Personal             Boone
# 297     4/2/2016 19:38    4/2/2016 22:36  Business      Jacksonville
# 299      4/3/2016 2:00     4/3/2016 4:16  Business          Florence
# 727    8/27/2016 16:15   8/27/2016 19:13  Business  Unknown Location
#
#                  STOP*   MILES*        PURPOSE*
# 1155               NaN  12204.7             NaN
# 269       Jacksonville    310.3  Customer Visit
# 270          Kissimmee    201.0         Meeting
# ...

# %%
df.sort_values(by=["START*","MILES*"],ascending =[True, False]).head(n=10)
# Out:
#            START_DATE*         END_DATE* CATEGORY*  START*          STOP*  \
# 906    11/4/2016 21:04   11/4/2016 21:20  Business   Agnew           Cory
# 911    11/6/2016 10:50   11/6/2016 11:04  Business   Agnew    Renaissance
# 908     11/5/2016 8:34    11/5/2016 8:43  Business   Agnew    Renaissance
# 910    11/5/2016 19:20   11/5/2016 19:28  Business   Agnew          Agnew
# 879   10/30/2016 12:58  10/30/2016 13:18  Business  Almond    Bryson City
# 1001  11/26/2016 17:36  11/26/2016 17:56  Business    Apex  Holly Springs
# 1033   12/9/2016 13:15   12/9/2016 13:43  Business    Apex           Cary
# 410     6/6/2016 21:08    6/6/2016 21:37  Business    Apex           Cary
# 647    8/10/2016 19:47   8/10/2016 20:02  Business    Apex           Cary
# 60     1/30/2016 18:09   1/30/2016 18:24  Business    Apex           Cary
#
#       MILES*        PURPOSE*
# 906      4.3             NaN
# 911      2.4             NaN
# 908      2.2             NaN
# 910      2.2             NaN
# ...

# %%
# Grouping

# %%
import pandas as pd
df = pd.read_csv("UberDrive.csv")
df.head(n=10)
# Out:
#        START_DATE*        END_DATE* CATEGORY*           START*  \
# 0   1/1/2016 21:11   1/1/2016 21:17  Business      Fort Pierce
# 1    1/2/2016 1:25    1/2/2016 1:37  Business      Fort Pierce
# 2   1/2/2016 20:25   1/2/2016 20:38  Business      Fort Pierce
# 3   1/5/2016 17:31   1/5/2016 17:45  Business      Fort Pierce
# 4   1/6/2016 14:42   1/6/2016 15:49  Business      Fort Pierce
# 5   1/6/2016 17:15   1/6/2016 17:19  Business  West Palm Beach
# 6   1/6/2016 17:30   1/6/2016 17:35  Business  West Palm Beach
# 7   1/7/2016 13:27   1/7/2016 13:33  Business             Cary
# 8   1/10/2016 8:05   1/10/2016 8:25  Business             Cary
# 9  1/10/2016 12:17  1/10/2016 12:44  Business          Jamaica
#
#              STOP*  MILES*         PURPOSE*
# 0      Fort Pierce     5.1   Meal/Entertain
# 1      Fort Pierce     5.0              NaN
# 2      Fort Pierce     4.8  Errand/Supplies
# 3      Fort Pierce     4.7          Meeting
# 4  West Palm Beach    63.7   Customer Visit
# ...

# %%
df.groupby("START*")["MILES*"].mean()  # we can also do it using aggrigation instead of .mean() we can also do .agg("mean")
# Out:
# START*
# Agnew                2.775000
# Almond              15.200000
# Apex                 5.341176
# Arabi               17.000000
# Arlington            4.900000
#                       ...
# West University      2.200000
# Weston               4.000000
# Westpark Place       2.182353
# Whitebridge          4.020588
# Winston Salem      133.600000
# Name: MILES*, Length: 177, dtype: float64

# %%
# Groupby summerize

# %%
df.groupby(["START*","STOP*"])["MILES*"].agg(["mean","sum"]).head(20)
# Out:
#                                                            mean    sum
# START*                    STOP*
# Agnew                     Agnew                        2.200000    2.2
#                           Cory                         4.300000    4.3
#                           Renaissance                  2.300000    4.6
# Almond                    Bryson City                 15.200000   15.2
# Apex                      Apex                         2.150000    4.3
#                           Cary                         5.792308   75.3
#                           Eagle Rock                   2.200000    2.2
#                           Holly Springs                9.000000    9.0
# Arabi                     Metairie                    17.000000   17.0
# Arlington                 Washington                   4.900000    4.9
# Arlington Park at Amberly Lexington Park at Amberly    1.300000    1.3
# Asheville                 Mebane                     195.900000  195.9
# ...

# %%
# Find most recent and the earliest travelled date and mean distance travelled for the each city.

# %%
import pandas as pd
df = pd.read_csv("UberDrive.csv")

# %%
# Lets remove the last row first 
df = df[:-1]
# Lets convert START_DATE* to Date and time
df["START_DATE*"] = pd.to_datetime(df["START_DATE*"])
df.head(10)
# Out:
#           START_DATE*        END_DATE* CATEGORY*           START*  \
# 0 2016-01-01 21:11:00   1/1/2016 21:17  Business      Fort Pierce
# 1 2016-01-02 01:25:00    1/2/2016 1:37  Business      Fort Pierce
# 2 2016-01-02 20:25:00   1/2/2016 20:38  Business      Fort Pierce
# 3 2016-01-05 17:31:00   1/5/2016 17:45  Business      Fort Pierce
# 4 2016-01-06 14:42:00   1/6/2016 15:49  Business      Fort Pierce
# 5 2016-01-06 17:15:00   1/6/2016 17:19  Business  West Palm Beach
# 6 2016-01-06 17:30:00   1/6/2016 17:35  Business  West Palm Beach
# 7 2016-01-07 13:27:00   1/7/2016 13:33  Business             Cary
# 8 2016-01-10 08:05:00   1/10/2016 8:25  Business             Cary
# 9 2016-01-10 12:17:00  1/10/2016 12:44  Business          Jamaica
#
#              STOP*  MILES*         PURPOSE*
# 0      Fort Pierce     5.1   Meal/Entertain
# 1      Fort Pierce     5.0              NaN
# 2      Fort Pierce     4.8  Errand/Supplies
# 3      Fort Pierce     4.7          Meeting
# ...

# %%
res = df.groupby(["START*","STOP*"]).agg({"MILES*" : ["mean"], "START_DATE*" : ["min","max"]})
res.reset_index(inplace = True)
res
res.columns = ["START_CITY", "END_CITY", "AVERAGE_DISTANCE", "EARLIEST_TRIP", "RECENT_TRIP"]
res
# Out:
#         START_CITY            END_CITY  AVERAGE_DISTANCE       EARLIEST_TRIP  \
# 0            Agnew               Agnew          2.200000 2016-11-05 19:20:00
# 1            Agnew                Cory          4.300000 2016-11-04 21:04:00
# 2            Agnew         Renaissance          2.300000 2016-11-05 08:34:00
# 3           Almond         Bryson City         15.200000 2016-10-30 12:58:00
# 4             Apex                Apex          2.150000 2016-08-10 18:49:00
# ..             ...                 ...               ...                 ...
# 356    Whitebridge         Wayne Ridge          7.975000 2016-03-01 18:47:00
# 357    Whitebridge      Westpark Place          2.242857 2016-01-26 16:24:00
# 358    Whitebridge         Whitebridge          2.014286 2016-03-08 16:13:00
# 359    Whitebridge  Williamsburg Manor          8.300000 2016-02-02 13:04:00
# 360  Winston Salem           Asheville        133.600000 2016-10-28 18:13:00
#
#             RECENT_TRIP
# ...
