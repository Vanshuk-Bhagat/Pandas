# %%
#Read CSV

# %%
import pandas as pd
csv = pd.read_csv("UberDrive.csv")
csv
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*         PURPOSE*
# 0          Fort Pierce      5.1   Meal/Entertain
# ...

# %%
csv = pd.read_csv("UberDrive.csv",nrows=2)
csv
# Out:
#       START_DATE*       END_DATE* CATEGORY*       START*        STOP*  MILES*  \
# 0  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce  Fort Pierce     5.1
# 1   1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce  Fort Pierce     5.0
#
#          PURPOSE*
# 0  Meal/Entertain
# 1             NaN

# %%
csv = pd.read_csv("UberDrive.csv", usecols=[0,3])
csv
# Out:
#            START_DATE*            START*
# 0       1/1/2016 21:11       Fort Pierce
# 1        1/2/2016 1:25       Fort Pierce
# 2       1/2/2016 20:25       Fort Pierce
# 3       1/5/2016 17:31       Fort Pierce
# 4       1/6/2016 14:42       Fort Pierce
# ...                ...               ...
# 1151  12/31/2016 13:24           Kar?chi
# 1152  12/31/2016 15:03  Unknown Location
# 1153  12/31/2016 21:32        Katunayake
# 1154  12/31/2016 22:08           Gampaha
# 1155            Totals               NaN
#
# [1156 rows x 2 columns]

# %%
csv = pd.read_csv("UberDrive.csv",usecols=["START_DATE*","END_DATE*"])
csv
# Out:
#            START_DATE*         END_DATE*
# 0       1/1/2016 21:11    1/1/2016 21:17
# 1        1/2/2016 1:25     1/2/2016 1:37
# 2       1/2/2016 20:25    1/2/2016 20:38
# 3       1/5/2016 17:31    1/5/2016 17:45
# 4       1/6/2016 14:42    1/6/2016 15:49
# ...                ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42
# 1152  12/31/2016 15:03  12/31/2016 15:38
# 1153  12/31/2016 21:32  12/31/2016 21:50
# 1154  12/31/2016 22:08  12/31/2016 23:51
# 1155            Totals               NaN
#
# [1156 rows x 2 columns]

# %%
csv = pd.read_csv("UberDrive.csv",skiprows=[0,1])
csv
# Out:
#          1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce  \
# 0       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 1       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 2       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# 3       1/6/2016 17:15    1/6/2016 17:19  Business   West Palm Beach
# 4       1/6/2016 17:30    1/6/2016 17:35  Business   West Palm Beach
# ...                ...               ...       ...               ...
# 1149  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1150  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1151  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1152  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1153            Totals               NaN       NaN               NaN
#
#          Fort Pierce.1        5       Unnamed: 6
# 0          Fort Pierce      4.8  Errand/Supplies
# ...

# %%
csv = pd.read_csv("UberDrive.csv",index_col="START_DATE*")
csv
# Out:
#                          END_DATE* CATEGORY*            START*  \
# START_DATE*
# 1/1/2016 21:11      1/1/2016 21:17  Business       Fort Pierce
# 1/2/2016 1:25        1/2/2016 1:37  Business       Fort Pierce
# 1/2/2016 20:25      1/2/2016 20:38  Business       Fort Pierce
# 1/5/2016 17:31      1/5/2016 17:45  Business       Fort Pierce
# 1/6/2016 14:42      1/6/2016 15:49  Business       Fort Pierce
# ...                            ...       ...               ...
# 12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# Totals                         NaN       NaN               NaN
#
#                              STOP*   MILES*         PURPOSE*
# START_DATE*
# 1/1/2016 21:11         Fort Pierce      5.1   Meal/Entertain
# ...

# %%
csv = pd.read_csv("UberDrive.csv",header = 2)
csv
# Out:
#          1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce  \
# 0       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 1       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 2       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# 3       1/6/2016 17:15    1/6/2016 17:19  Business   West Palm Beach
# 4       1/6/2016 17:30    1/6/2016 17:35  Business   West Palm Beach
# ...                ...               ...       ...               ...
# 1149  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1150  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1151  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1152  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1153            Totals               NaN       NaN               NaN
#
#          Fort Pierce.1        5       Unnamed: 6
# 0          Fort Pierce      4.8  Errand/Supplies
# ...

# %%
csv = pd.read_csv("UberDrive.csv",names=["cols"])
csv
# Out:
#                                                                                                   cols
# START_DATE*      END_DATE*        CATEGORY* START*           STOP*            MILES*          PURPOSE*
# 1/1/2016 21:11   1/1/2016 21:17   Business  Fort Pierce      Fort Pierce      5.1       Meal/Entertain
# 1/2/2016 1:25    1/2/2016 1:37    Business  Fort Pierce      Fort Pierce      5                    NaN
# 1/2/2016 20:25   1/2/2016 20:38   Business  Fort Pierce      Fort Pierce      4.8      Errand/Supplies
# 1/5/2016 17:31   1/5/2016 17:45   Business  Fort Pierce      Fort Pierce      4.7              Meeting
# ...                                                                                                ...
# 12/31/2016 13:24 12/31/2016 13:42 Business  Kar?chi          Unknown Location 3.9       Temporary Site
# 12/31/2016 15:03 12/31/2016 15:38 Business  Unknown Location Unknown Location 16.2             Meeting
# ...

# %%
csv = pd.read_csv("UberDrive.csv",names=["col0","col1","col2","col3"])
csv
# Out:
#                                                          col0  \
# START_DATE*      END_DATE*        CATEGORY*            START*
# 1/1/2016 21:11   1/1/2016 21:17   Business        Fort Pierce
# 1/2/2016 1:25    1/2/2016 1:37    Business        Fort Pierce
# 1/2/2016 20:25   1/2/2016 20:38   Business        Fort Pierce
# 1/5/2016 17:31   1/5/2016 17:45   Business        Fort Pierce
# ...                                                       ...
# 12/31/2016 13:24 12/31/2016 13:42 Business            Kar?chi
# 12/31/2016 15:03 12/31/2016 15:38 Business   Unknown Location
# 12/31/2016 21:32 12/31/2016 21:50 Business         Katunayake
# 12/31/2016 22:08 12/31/2016 23:51 Business            Gampaha
# Totals           NaN              NaN                     NaN
#
#                                                          col1     col2  \
# START_DATE*      END_DATE*        CATEGORY*             STOP*   MILES*
# 1/1/2016 21:11   1/1/2016 21:17   Business        Fort Pierce      5.1
# ...

# %%
csv
# Out:
#                                                          col0  \
# START_DATE*      END_DATE*        CATEGORY*            START*
# 1/1/2016 21:11   1/1/2016 21:17   Business        Fort Pierce
# 1/2/2016 1:25    1/2/2016 1:37    Business        Fort Pierce
# 1/2/2016 20:25   1/2/2016 20:38   Business        Fort Pierce
# 1/5/2016 17:31   1/5/2016 17:45   Business        Fort Pierce
# ...                                                       ...
# 12/31/2016 13:24 12/31/2016 13:42 Business            Kar?chi
# 12/31/2016 15:03 12/31/2016 15:38 Business   Unknown Location
# 12/31/2016 21:32 12/31/2016 21:50 Business         Katunayake
# 12/31/2016 22:08 12/31/2016 23:51 Business            Gampaha
# Totals           NaN              NaN                     NaN
#
#                                                          col1     col2  \
# START_DATE*      END_DATE*        CATEGORY*             STOP*   MILES*
# 1/1/2016 21:11   1/1/2016 21:17   Business        Fort Pierce      5.1
# ...

# %%
csv = pd.read_csv("UberDrive.csv",dtype={"MILES*":"float"})
csv
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*         PURPOSE*
# 0          Fort Pierce      5.1   Meal/Entertain
# ...
